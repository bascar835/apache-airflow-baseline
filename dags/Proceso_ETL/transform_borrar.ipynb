# %%
import pandas as pd

# Cargar el archivo CSV de energía renovable
df = pd.read_csv('data/energia_renovable.csv',sep=',')


# Transponer los datos temporales
df2 = df.transpose()

df2

df2.columns = df2.iloc[0]

df2.columns

df2

df2.index

df3 = df2.iloc[4:,]

df3 = df3.drop(df3.index[-1])

df3.index

df3.index = df3.index.astype(int)   # Transformar los datos a enteros

df3.index

df3 = df3[(df3.index >= 1990) & (df3.index <= 2014)]

# Calcular emisiones promedio 

df3.mean()
# Out:
# Country Name
# Aruba                           2.734205
# Africa Eastern and Southern    17.169654
# Afghanistan                     74.38829
# Africa Western and Central     47.157185
# Angola                         74.900081
#                                  ...
# Kosovo                          1.232011
# Yemen, Rep.                          0.0
# South Africa                    0.731494
# Zambia                         99.405851
# Zimbabwe                       48.720433
# Length: 266, dtype: object

# %%
import pandas as pd

# Cargar el archivo CSV de energía renovable
df1 = pd.read_csv('data/energia_renovable.csv',sep=',')
df2 = pd.read_csv('data/world_population.csv',sep=',')

# Unir las tablas por las columnas especificadas
merged_df = pd.merge(
    df2, df1,
    left_on="Country Name",  # Columna en df2
    right_on="Country/Territory",  # Columna en df1
    how="inner"  # Tipo de unión (inner conserva solo coincidencias)
)

# Seleccionar solo las columnas relevantes
result_df = merged_df[["Country Name", "Year", "Electricity", "Population"]]

result_df

# %%
import pandas as pd

# Cargar el archivo CSV de energía renovable
df1 = pd.read_csv('data/energia_renovable.csv',sep=',')
df2 = pd.read_csv('data/world_population.csv',sep=',')

# Cargar el archivo CSV de energía renovable


# Transponer los datos temporales
df1 = df1.transpose()
df1.columns = df1.iloc[0]
df1
# Out:
# Country Name                                                Aruba  \
# Country Name                                                Aruba
# Country Code                                                  ABW
# Indicator Name  Renewable electricity output (% of total elect...
# Indicator Code                                     EG.ELC.RNEW.ZS
# 1960                                                          NaN
# ...                                                           ...
# 2020                                                          NaN
# 2021                                                          NaN
# 2022                                                          NaN
# 2023                                                          NaN
# Unnamed: 68                                                   NaN
#
# Country Name                          Africa Eastern and Southern  \
# Country Name                          Africa Eastern and Southern
# Country Code                                                  AFE
# Indicator Name  Renewable electricity output (% of total elect...
# Indicator Code                                     EG.ELC.RNEW.ZS
# 1960                                                          NaN
# ...                                                           ...
# 2020                                                          NaN
# 2021                                                          NaN
# 2022                                                          NaN
# 2023                                                          NaN
# Unnamed: 68                                                   NaN
#
# Country Name                                          Afghanistan  \
# Country Name                                          Afghanistan
# Country Code                                                  AFG
# Indicator Name  Renewable electricity output (% of total elect...
# Indicator Code                                     EG.ELC.RNEW.ZS
# 1960                                                          NaN
# ...                                                           ...
# 2020                                                          NaN
# 2021                                                          NaN
# 2022                                                          NaN
# 2023                                                          NaN
# Unnamed: 68                                                   NaN
#
# Country Name                           Africa Western and Central  \
# Country Name                           Africa Western and Central
# Country Code                                                  AFW
# Indicator Name  Renewable electricity output (% of total elect...
# Indicator Code                                     EG.ELC.RNEW.ZS
# 1960                                                          NaN
# ...                                                           ...
# 2020                                                          NaN
# 2021                                                          NaN
# 2022                                                          NaN
# 2023                                                          NaN
# Unnamed: 68                                                   NaN
#
# Country Name                                               Angola  \
# Country Name                                               Angola
# Country Code                                                  AGO
# Indicator Name  Renewable electricity output (% of total elect...
# Indicator Code                                     EG.ELC.RNEW.ZS
# 1960                                                          NaN
# ...                                                           ...
# 2020                                                          NaN
# 2021                                                          NaN
# 2022                                                          NaN
# 2023                                                          NaN
# Unnamed: 68                                                   NaN
#
# Country Name                                              Albania  \
# Country Name                                              Albania
# Country Code                                                  ALB
# Indicator Name  Renewable electricity output (% of total elect...
# Indicator Code                                     EG.ELC.RNEW.ZS
# 1960                                                          NaN
# ...                                                           ...
# 2020                                                          NaN
# 2021                                                          NaN
# 2022                                                          NaN
# 2023                                                          NaN
# Unnamed: 68                                                   NaN
#
# Country Name                                              Andorra  \
# Country Name                                              Andorra
# Country Code                                                  AND
# Indicator Name  Renewable electricity output (% of total elect...
# Indicator Code                                     EG.ELC.RNEW.ZS
# 1960                                                          NaN
# ...                                                           ...
# 2020                                                          NaN
# 2021                                                          NaN
# 2022                                                          NaN
# 2023                                                          NaN
# Unnamed: 68                                                   NaN
#
# Country Name                                           Arab World  \
# Country Name                                           Arab World
# Country Code                                                  ARB
# Indicator Name  Renewable electricity output (% of total elect...
# Indicator Code                                     EG.ELC.RNEW.ZS
# 1960                                                          NaN
# ...                                                           ...
# 2020                                                          NaN
# 2021                                                          NaN
# 2022                                                          NaN
# 2023                                                          NaN
# Unnamed: 68                                                   NaN
#
# Country Name                                 United Arab Emirates  \
# Country Name                                 United Arab Emirates
# Country Code                                                  ARE
# Indicator Name  Renewable electricity output (% of total elect...
# Indicator Code                                     EG.ELC.RNEW.ZS
# 1960                                                          NaN
# ...                                                           ...
# 2020                                                          NaN
# 2021                                                          NaN
# 2022                                                          NaN
# 2023                                                          NaN
# Unnamed: 68                                                   NaN
#
# Country Name                                            Argentina  ...  \
# Country Name                                            Argentina  ...
# Country Code                                                  ARG  ...
# Indicator Name  Renewable electricity output (% of total elect...  ...
# Indicator Code                                     EG.ELC.RNEW.ZS  ...
# 1960                                                          NaN  ...
# ...                                                           ...  ...
# 2020                                                          NaN  ...
# 2021                                                          NaN  ...
# 2022                                                          NaN  ...
# 2023                                                          NaN  ...
# Unnamed: 68                                                   NaN  ...
#
# Country Name                                Virgin Islands (U.S.)  \
# Country Name                                Virgin Islands (U.S.)
# Country Code                                                  VIR
# Indicator Name  Renewable electricity output (% of total elect...
# Indicator Code                                     EG.ELC.RNEW.ZS
# 1960                                                          NaN
# ...                                                           ...
# 2020                                                          NaN
# 2021                                                          NaN
# 2022                                                          NaN
# 2023                                                          NaN
# Unnamed: 68                                                   NaN
#
# Country Name                                             Viet Nam  \
# Country Name                                             Viet Nam
# Country Code                                                  VNM
# Indicator Name  Renewable electricity output (% of total elect...
# Indicator Code                                     EG.ELC.RNEW.ZS
# 1960                                                          NaN
# ...                                                           ...
# 2020                                                          NaN
# 2021                                                          NaN
# 2022                                                          NaN
# 2023                                                          NaN
# Unnamed: 68                                                   NaN
#
# Country Name                                              Vanuatu  \
# Country Name                                              Vanuatu
# Country Code                                                  VUT
# Indicator Name  Renewable electricity output (% of total elect...
# Indicator Code                                     EG.ELC.RNEW.ZS
# 1960                                                          NaN
# ...                                                           ...
# 2020                                                          NaN
# 2021                                                          NaN
# 2022                                                          NaN
# 2023                                                          NaN
# Unnamed: 68                                                   NaN
#
# Country Name                                                World  \
# Country Name                                                World
# Country Code                                                  WLD
# Indicator Name  Renewable electricity output (% of total elect...
# Indicator Code                                     EG.ELC.RNEW.ZS
# 1960                                                          NaN
# ...                                                           ...
# 2020                                                          NaN
# 2021                                                          NaN
# 2022                                                          NaN
# 2023                                                          NaN
# Unnamed: 68                                                   NaN
#
# Country Name                                                Samoa  \
# Country Name                                                Samoa
# Country Code                                                  WSM
# Indicator Name  Renewable electricity output (% of total elect...
# Indicator Code                                     EG.ELC.RNEW.ZS
# 1960                                                          NaN
# ...                                                           ...
# 2020                                                          NaN
# 2021                                                          NaN
# 2022                                                          NaN
# 2023                                                          NaN
# Unnamed: 68                                                   NaN
#
# Country Name                                               Kosovo  \
# Country Name                                               Kosovo
# Country Code                                                  XKX
# Indicator Name  Renewable electricity output (% of total elect...
# Indicator Code                                     EG.ELC.RNEW.ZS
# 1960                                                          NaN
# ...                                                           ...
# 2020                                                          NaN
# 2021                                                          NaN
# 2022                                                          NaN
# 2023                                                          NaN
# Unnamed: 68                                                   NaN
#
# Country Name                                          Yemen, Rep.  \
# Country Name                                          Yemen, Rep.
# Country Code                                                  YEM
# Indicator Name  Renewable electricity output (% of total elect...
# Indicator Code                                     EG.ELC.RNEW.ZS
# 1960                                                          NaN
# ...                                                           ...
# 2020                                                          NaN
# 2021                                                          NaN
# 2022                                                          NaN
# 2023                                                          NaN
# Unnamed: 68                                                   NaN
#
# Country Name                                         South Africa  \
# Country Name                                         South Africa
# Country Code                                                  ZAF
# Indicator Name  Renewable electricity output (% of total elect...
# Indicator Code                                     EG.ELC.RNEW.ZS
# 1960                                                          NaN
# ...                                                           ...
# 2020                                                          NaN
# 2021                                                          NaN
# 2022                                                          NaN
# 2023                                                          NaN
# Unnamed: 68                                                   NaN
#
# Country Name                                               Zambia  \
# Country Name                                               Zambia
# Country Code                                                  ZMB
# Indicator Name  Renewable electricity output (% of total elect...
# Indicator Code                                     EG.ELC.RNEW.ZS
# 1960                                                          NaN
# ...                                                           ...
# 2020                                                          NaN
# 2021                                                          NaN
# 2022                                                          NaN
# 2023                                                          NaN
# Unnamed: 68                                                   NaN
#
# Country Name                                             Zimbabwe
# Country Name                                             Zimbabwe
# Country Code                                                  ZWE
# Indicator Name  Renewable electricity output (% of total elect...
# Indicator Code                                     EG.ELC.RNEW.ZS
# 1960                                                          NaN
# ...                                                           ...
# 2020                                                          NaN
# 2021                                                          NaN
# 2022                                                          NaN
# 2023                                                          NaN
# Unnamed: 68                                                   NaN
#
# [69 rows x 266 columns]

# %% [markdown]
# # Datos de Energia Renovable

# %%
import pandas as pd

# Cargar el archivo CSV de energía renovable
df1 = pd.read_csv('data/energia_renovable.csv',sep=',')
df2 = pd.read_csv('data/world_population.csv',sep=',')

# Cargar el archivo CSV de energía renovable


# Transponer los datos temporales
df1 = df1.transpose()

df1.columns = df1.iloc[0]

df1 = df1.iloc[4:,]

df1 = df1.drop(df1.index[-1])

df1.index = df1.index.astype(int)   # Transformar los datos a enteros

df1 = df1[(df1.index >= 1990) & (df1.index <= 2014)]

media_por_columna = df1.mean()

media_por_columna_df = pd.DataFrame(media_por_columna).T 

media_por_columna_df.index = ['mean_energia']

df1 = pd.concat([df1, media_por_columna_df])

df2["mean1990-2014"] = (df2["2015 Population"] + df2["2010 Population"] + df2["2000 Population"] + df2["1990 Population"]) / 4

df2 = df2[["Country/Territory", "mean1990-2014"]]

poblacion_media = dict(zip(df2['Country/Territory'], df2['mean1990-2014']))

df1.loc['Population_Mean'] = df1.columns.map(poblacion_media)

df1.loc['Electricidad_per_capita'] = df1.loc["mean_energia"] / df1.loc["Population_Mean"]

#df1.rename(columns={"Country Name": "Country"}, inplace=True)

df1 = df1.loc[['Electricidad_per_capita','mean_energia','Population_Mean']].T


df1["Country"] = df1.index

df1
# Out:
#                             Electricidad_per_capita mean_energia  \
# Country Name
# Aruba                                       0.00003     2.734205
# Africa Eastern and Southern                     NaN    17.169654
# Afghanistan                                0.000003     74.38829
# Africa Western and Central                      NaN    47.157185
# Angola                                     0.000004    74.900081
# ...                                             ...          ...
# Kosovo                                          NaN     1.232011
# Yemen, Rep.                                     NaN          0.0
# South Africa                                    0.0     0.731494
# Zambia                                     0.000008    99.405851
# Zimbabwe                                   0.000004    48.720433
#
#                             Population_Mean                      Country
# Country Name
# Aruba                              89852.75                        Aruba
# Africa Eastern and Southern             NaN  Africa Eastern and Southern
# Afghanistan                     23045237.25                  Afghanistan
# Africa Western and Central              NaN   Africa Western and Central
# Angola                           19928651.5                       Angola
# ...                                     ...                          ...
# Kosovo                                  NaN                       Kosovo
# Yemen, Rep.                             NaN                  Yemen, Rep.
# South Africa                    48588065.25                 South Africa
# Zambia                          11904463.25                       Zambia
# Zimbabwe                        12235819.25                     Zimbabwe
#
# [266 rows x 4 columns]

# %% [markdown]
# # Global Greenhouse Gas Emissions

# %%
df = pd.read_csv('data/global_ghg_emissions.csv',sep=',')
df1 = pd.read_csv('data/world_population.csv',sep=',')
# Agrupar por país y calcular el promedio de emisiones
#df = df.groupby("country_or_area")["value"].mean()

df = df.groupby("country_or_area")["value"].mean().reset_index()

df_merged = pd.merge(
    df, 
    df1, 
    left_on="country_or_area", 
    right_on="Country/Territory", 
    how="inner"  # Tipo de unión: inner, left, right, outer
)

#df.to_csv("gas.csv", index=False)

#df = pd.read_csv('gas.csv')

df_merged["Population_media"] = (df_merged["2022 Population"]+df_merged["2020 Population"]+df_merged["2015 Population"]+df_merged["2000 Population"]+df_merged["1990 Population"]+df_merged["1980 Population"]+df_merged["1970 Population"])/7

df_merged = df_merged.rename(columns={"value": "Emisiones_gas"})

df_merged["Emisiones_per_capita"] = df_merged["Emisiones_gas"]/df_merged["Population_media"]

df_merged[["country_or_area","Population_media","Emisiones_gas","Emisiones_per_capita"]]

df_merged = df_merged[["country_or_area","Population_media","Emisiones_gas","Emisiones_per_capita"]].T

df_merged.columns = df_merged.iloc[0]

df_merged = df_merged.drop(df_merged.index[0])

df_merged = df_merged.T

df_merged["Country"] = df_merged.index

df_merged
# Out:
#                  Population_media  Emisiones_gas Emisiones_per_capita  \
# country_or_area
# Australia              19862146.0  182187.274191             0.009173
# Austria                 8170262.0    28140.83461             0.003444
# Belarus            9791764.857143   47145.084054             0.004815
# Belgium           10592602.142857   51824.463082             0.004893
# Bulgaria           7928486.571429   21622.049086             0.002727
# Canada            30908823.142857  237691.253864              0.00769
# Croatia            4425280.571429   10979.664147             0.002481
# Cyprus              961881.857143    3532.154214             0.003672
# Czech Republic    10307206.142857   58330.175163             0.005659
# Denmark            5417047.285714   27347.102027             0.005048
# Estonia            1396670.857143    9042.185919             0.006474
# Finland            5156923.857143   27119.721266             0.005259
# France            58890316.571429  180049.548523             0.003057
# Germany           80825030.857143  312367.267845             0.003865
# Greece            10128032.714286   44703.957313             0.004414
# Hungary                10164888.0   27850.240821              0.00274
# Iceland             291405.714286    1538.565341              0.00528
# Ireland            4031190.857143   22056.186323             0.005471
# Italy             57449633.571429  182413.163455             0.003175
# Japan            121425514.714286  451633.170796             0.003719
# Latvia             2255861.428571     6065.84819             0.002689
# Liechtenstein             31903.0      73.858592             0.002315
# Lithuania          3235846.285714   10896.219409             0.003367
# Luxembourg          481054.857143    3833.000464             0.007968
# Malta               416975.285714    1156.903645             0.002775
# Monaco               32041.571429      41.082545             0.001282
# Netherlands       15721633.428571    81631.18511             0.005192
# New Zealand        4008699.285714   28890.243745             0.007207
# Norway             4671239.142857   20169.325244             0.004318
# Poland            37344530.714286  163111.416912             0.004368
# Portugal           9958763.857143   30622.772697             0.003075
# Romania           20830190.857143   58613.142044             0.002814
# Slovakia           5237046.142857   19824.653352             0.003785
# Slovenia           1990223.714286     7401.16444             0.003719
# Spain             41752800.285714  101039.412533              0.00242
# Sweden             9218082.714286   25393.442421             0.002755
# Switzerland        7436415.571429   19194.737785             0.002581
# Turkey            63884370.714286  137079.509325             0.002146
# Ukraine           46616649.571429  200441.234581               0.0043
# United Kingdom    61118536.142857  174001.432329             0.002847
#
#                         Country
# country_or_area
# Australia             Australia
# Austria                 Austria
# Belarus                 Belarus
# Belgium                 Belgium
# Bulgaria               Bulgaria
# Canada                   Canada
# Croatia                 Croatia
# Cyprus                   Cyprus
# Czech Republic   Czech Republic
# Denmark                 Denmark
# Estonia                 Estonia
# Finland                 Finland
# France                   France
# Germany                 Germany
# Greece                   Greece
# Hungary                 Hungary
# Iceland                 Iceland
# Ireland                 Ireland
# Italy                     Italy
# Japan                     Japan
# Latvia                   Latvia
# Liechtenstein     Liechtenstein
# Lithuania             Lithuania
# Luxembourg           Luxembourg
# Malta                     Malta
# Monaco                   Monaco
# Netherlands         Netherlands
# New Zealand         New Zealand
# Norway                   Norway
# Poland                   Poland
# Portugal               Portugal
# Romania                 Romania
# Slovakia               Slovakia
# Slovenia               Slovenia
# Spain                     Spain
# Sweden                   Sweden
# Switzerland         Switzerland
# Turkey                   Turkey
# Ukraine                 Ukraine
# United Kingdom   United Kingdom

# %% [markdown]
# # PIB Mundial

# %%
df = pd.read_excel("data/pib.xlsx", sheet_name="Full data")
#df1 = pd.read_csv('data/world_population.csv',sep=',')

df.head()

df = df.rename(columns={"gdppc": "PIB_per_capita"})

df = df.rename(columns={"pop": "Poblacion"})


df = df.groupby("country")[["PIB_per_capita","Poblacion"]].mean().reset_index()


df["PIB"] = df["PIB_per_capita"] *df["Poblacion"]
#df_merged["country","gdppc" ]

df = df.T

df.columns = df.iloc[0]

df = df.drop(df.index[0])

df = df.T

df["Country"] = df.index

df

col4 = df.columns[3]  # La cuarta columna está en el índice 3

# Paso 2: Reordenar las columnas
df = df[[col4] + [col for col in df.columns if col != col4]]

df
# Out:
#                                                                Country  \
# country
# Afghanistan                                                Afghanistan
# Albania                                                        Albania
# Algeria                                                        Algeria
# Angola                                                          Angola
# Argentina                                                    Argentina
# ...                                                                ...
# Venezuela (Bolivarian Republic of)  Venezuela (Bolivarian Republic of)
# Viet Nam                                                      Viet Nam
# Yemen                                                            Yemen
# Zambia                                                          Zambia
# Zimbabwe                                                      Zimbabwe
#
#                                    PIB_per_capita     Poblacion  \
# country
# Afghanistan                           1210.213944   17877.33843
# Albania                               4669.542353   1921.507826
# Algeria                               6225.735465  21477.896654
# Angola                                3143.536972  10153.158658
# Argentina                             8879.557435  22150.153205
# ...                                           ...           ...
# Venezuela (Bolivarian Republic of)    6630.605876   9763.622348
# Viet Nam                              2515.654325  60393.164355
# Yemen                                 2995.336002  13246.965447
# Zambia                                 1455.14484   8457.150233
# Zimbabwe                              1537.886454   8786.328055
#
#                                                  PIB
# country
# Afghanistan                          21635404.244443
# Albania                               8972562.175717
# Algeria                             133715702.923436
# Angola                               31916829.625879
# Argentina                           196683557.577333
# ...                                              ...
# Venezuela (Bolivarian Republic of)   64738731.712383
# Viet Nam                            151928325.109753
# Yemen                                39679112.525451
# Zambia                               12306378.526688
# Zimbabwe                             13512374.893392
#
# [169 rows x 4 columns]

# %%
df_merged = pd.merge(
    df, 
    df1, 
    left_on="country", 
    right_on="Country/Territory", 
    how="inner"  # Tipo de unión: inner, left, right, outer
)
